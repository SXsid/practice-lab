# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display ,Markdown,update_display

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'gemma3:270m'

# %%
load_dotenv(override=True)
key=os.getenv("OPENAI_API_KEY")
if len(key)<10:
    print("key is miissing ")
else:
    print("looks fine till now")
# Out:
# looks fine till now

# %%
# set up environment
ollama_base_url="http://localhost:11434/v1"
ollama_api_key="ollama"

openai=OpenAI()
ollama=OpenAI(base_url=ollama_base_url,api_key=ollama_api_key)

# %%
# here is the question; type over this to ask something new

def user_prompt(question):
    return  f"""
Please explain what this code does and why:
{question}
"""

# %%
system_prompt="""
You are a senior eng with in a fourtune 500 ,
you have giive a role to train thee new junior 
they will ask you silly questiion:
for every question you have evalut the difficulty level of the question
if question ==easy :
    just reposes with a query that they can pasxte of google and they will geet async
if it's mediumexaplin some concept that is need and repadt with the seearching query or even most medium probl are not hardthey are ambigous
you what you can do here is  ask clairfication question about concept or you leave some idea to tiinker


for expamle 
find a graph if iit's cuycle with the value they drop whole quessitn  ,you will ask thme can you descibe me you approch or how you think a cycle will be formed 
in graph how you will see with those data ,like that

and lasst for hard qustion you have to iterae expalin solowly but ehre is most delticate you have to adapt how slow user is undetastng tackle step by step
undestatnd user learning pattern ,stop them for deviateing ecouragnge tought processs.


*IMPORTANT*
reponses your output in MARKDOWN  not inside code block
"""

# %%
# Get gpt-4o-mini to answer, with streaming
chunk=openai.chat.completions.create(model=MODEL_GPT,messages=[{
    "role":"system","content":system_prompt
},{"role":"user","content":user_prompt("""
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
Cell In[33], line 8
      6 handle=display(Markdown(res),display_id=True)
      7 for text in chunk:
----> 8     res+=text.choices[0].delta.content
      9     update_display(Markdown(res),display_id=handle.display_id)

TypeError: can only concatenate str (not "NoneType") to str
""")}],stream=True)
res=""
handle=display(Markdown(res),display_id=True)
for text in chunk:
    res+=text.choices[0].delta.content or ''
    update_display(Markdown(res),display_id=handle.display_id)
# Out:
# This seems to be an error message generated from a Python code snippet. Let's break down the elements involved:
#
# 1. **Code Context**: The code attempts to concatenate a string `res` with `text.choices[0].delta.content`. The error indicates that `text.choices[0].delta.content` is returning `None`, which cannot be concatenated to a string.
#
# 2. **Understanding the Error**:
#    - The error is a `TypeError` that states "can only concatenate str (not 'NoneType') to str". This typically means that the program is trying to combine a string with a value that does not represent anything (i.e., `None`).
#    - In Python, you can only concatenate strings with strings. If one of the items is `None`, the operation fails.
#
# ### Explanation Steps:
# - Check what `text.choices[0].delta.content` returns. If it is `None`, this is what causes the error.
# - You might want to ensure that `text.choices[0].delta.content` is not `None` before attempting to concatenate it with `res`.
#
# ...

# %%
# Get Llama 3.2 to answer

chunk=ollama.chat.completions.create(model=MODEL_LLAMA,messages=[{
    "role":"system","content":system_prompt
},{"role":"user","content":user_prompt("""
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
Cell In[33], line 8
      6 handle=display(Markdown(res),display_id=True)
      7 for text in chunk:
----> 8     res+=text.choices[0].delta.content
      9     update_display(Markdown(res),display_id=handle.display_id)

TypeError: can only concatenate str (not "NoneType") to str
""")}],stream=True)
res=""
display_handle=display(Markdown(res),display_id=True)
for text in chunk:
    res+=text.choices[0].delta.content or ''
    update_display(Markdown(res),display_id=display_handle.display_id)
# Out:
# ```python
# import pandas as pd
# import re
# import networkx as nx
#
# def train_junior_learners(question, queries):
#     """
#     Trains a junior learning set by asking questions based on the difficulty level of the query.
#     The question is converted into a graph structure with value drop-off nodes and
#     the data is visualized using a graph.
#
#     Args:
#         question: The question to be trained.
#         queries: A list of search queries, each representing a different difficulty level.
#
#     Returns:
#         A list of dictionaries, where each dictionary represents a junior learner and its training data.
#         Returns an empty list if there is no valid training set.
#     """
#
#     try:
#         df = pd.DataFrame()
#         df['learning_data'] = []
#         for question in queries:
#             try:
#                 df['question'] = question.split(" ")
# ...
